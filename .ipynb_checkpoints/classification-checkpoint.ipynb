# %%
import torch
import matplotlib.pyplot as plt
# %matplotlib inline

# 假数据
n_data = torch.ones(100, 2)         # 数据的基本形态
x0 = torch.normal(2*n_data, 1)      # 类型0 x data (tensor), shape=(100, 2)
y0 = torch.zeros(100)               # 类型0 y data (tensor), shape=(100, 1)
# print(
#         "\nn_data:",n_data,
#         "\nx0:",x0,
#         "\ny0:",y0
# )

# %%
x1 = torch.normal(-2*n_data, 1)     # 类型1 x data (tensor), shape=(100, 1)
y1 = torch.ones(100)                # 类型1 y data (tensor), shape=(100, 1)

# 注意 x, y 数据的数据形式是一定要像下面一样 (torch.cat 是在合并数据)
x = torch.cat((x0, x1), 0).type(torch.FloatTensor)  # FloatTensor = 32-bit floating
y = torch.cat((y0, y1), ).type(torch.LongTensor)    # LongTensor = 64-bit integer
# print(x,y)

# %%
plt.scatter(x.data.numpy()[:, 0], x.data.numpy()[:, 1], c=y.data.numpy(), s=100, lw=0, cmap='RdYlGn')
plt.show()

# 画图
# plt.scatter(x.data.numpy(), y.data.numpy())
# plt.show()

# %%
class Net(torch.nn.Module):     # 继承 torch 的 Module
    def __init__(self, n_feature, n_hidden, n_output):
        super(Net, self).__init__()     # 继承 __init__ 功能
        self.hidden = torch.nn.Linear(n_feature, n_hidden)   # 隐藏层线性输出
        self.out = torch.nn.Linear(n_hidden, n_output)       # 输出层线性输出

    def forward(self, x):
        # 正向传播输入值, 神经网络分析出输出值
        x = torch.relu(self.hidden(x))      # 激励函数(隐藏层的线性值)
        x = self.out(x)                 # 输出值, 但是这个不是预测值, 预测值还需要再另外计算
        return x

net = Net(n_feature=2, n_hidden=10, n_output=2) # 几个类别就几个 output

print(net)  # net 的结构
# Out:
# Net(
#   (hidden): Linear(in_features=2, out_features=10, bias=True)
#   (out): Linear(in_features=10, out_features=2, bias=True)
# )

# %%
# optimizer 是训练的工具
optimizer = torch.optim.SGD(net.parameters(), lr=0.02)  # 传入 net 的所有参数, 学习率
# 算误差的时候, 注意真实值!不是! one-hot 形式的, 而是1D Tensor, (batch,)
# 但是预测值是2D tensor (batch, n_classes)

# 分类问题常用的损失函数为交叉熵( Cross Entropy Loss)
loss_func = torch.nn.CrossEntropyLoss()

for t in range(100):
    out = net(x)     # 喂给 net 训练数据 x, 输出分析值

    loss = loss_func(out, y)     # 计算两者的误差

    optimizer.zero_grad()   # 清空上一步的残余更新参数值
    loss.backward()         # 误差反向传播, 计算参数更新值
    optimizer.step()        # 将参数更新值施加到 net 的 parameters 上
    if(t%10 == 0)
        print([p for p in net.parameters()],"\n")
# Out:
# [Parameter containing:
# tensor([[ 0.6848,  0.4951],
#         [ 0.6361,  0.0965],
#         [ 0.3522, -0.3037],
#         [ 0.6040, -0.1693],
#         [-0.4129,  0.1988],
#         [-0.6625,  0.3222],
#         [-0.6552, -0.6366],
#         [-0.1412,  0.5224],
#         [ 0.6253,  0.4803],
#         [ 0.4541, -0.1187]], requires_grad=True), Parameter containing:
# tensor([ 0.4577, -0.2395, -0.1703,  0.3703,  0.1584, -0.2869,  0.6593,  0.5753,
#         -0.1237, -0.0031], requires_grad=True), Parameter containing:
# tensor([[ 0.1367, -0.1490, -0.0791,  0.2817, -0.2867,  0.1520, -0.1638, -0.0642,
#          -0.2695,  0.2892],
#         [-0.1102, -0.0783,  0.2073, -0.2429, -0.0640,  0.2557,  0.0663, -0.0613,
#           0.2109, -0.1005]], requires_grad=True), Parameter containing:
# tensor([0.0919, 0.2428], requires_grad=True)]
#
# [Parameter containing:
# tensor([[ 0.6867,  0.4974],
#         [ 0.6356,  0.0958],
#         [ 0.3509, -0.3048],
#         [ 0.6083, -0.1641],
#         [-0.4143,  0.1969],
#         [-0.6629,  0.3217],
#         [-0.6563, -0.6378],
#         [-0.1412,  0.5224],
#         [ 0.6217,  0.4760],
#         [ 0.4571, -0.1157]], requires_grad=True), Parameter containing:
# tensor([ 0.4588, -0.2398, -0.1704,  0.3720,  0.1586, -0.2868,  0.6598,  0.5753,
#         -0.1258, -0.0017], requires_grad=True), Parameter containing:
# tensor([[ 0.1483, -0.1443, -0.0788,  0.2862, -0.2876,  0.1509, -0.1716, -0.0584,
#          -0.2609,  0.2916],
#         [-0.1218, -0.0830,  0.2070, -0.2474, -0.0631,  0.2568,  0.0742, -0.0671,
#           0.2023, -0.1030]], requires_grad=True), Parameter containing:
# tensor([0.0938, 0.2410], requires_grad=True)]
#
# [Parameter containing:
# tensor([[ 0.6885,  0.4996],
#         [ 0.6352,  0.0953],
#         [ 0.3498, -0.3059],
#         [ 0.6122, -0.1592],
#         [-0.4155,  0.1952],
#         [-0.6633,  0.3212],
#         [-0.6575, -0.6389],
#         [-0.1412,  0.5224],
#         [ 0.6186,  0.4722],
#         [ 0.4597, -0.1129]], requires_grad=True), Parameter containing:
# tensor([ 4.5984e-01, -2.3999e-01, -1.7053e-01,  3.7372e-01,  1.5872e-01,
#         -2.8668e-01,  6.6034e-01,  5.7534e-01, -1.2762e-01, -3.6745e-04],
#        requires_grad=True), Parameter containing:
# tensor([[ 0.1588, -0.1402, -0.0786,  0.2903, -0.2886,  0.1499, -0.1792, -0.0532,
#          -0.2533,  0.2939],
#         [-0.1323, -0.0872,  0.2068, -0.2515, -0.0622,  0.2578,  0.0817, -0.0723,
#           0.1947, -0.1052]], requires_grad=True), Parameter containing:
# tensor([0.0953, 0.2394], requires_grad=True)]
#
# [Parameter containing:
# tensor([[ 0.6902,  0.5018],
#         [ 0.6349,  0.0949],
#         [ 0.3487, -0.3069],
#         [ 0.6157, -0.1546],
#         [-0.4167,  0.1935],
#         [-0.6637,  0.3208],
#         [-0.6587, -0.6401],
#         [-0.1410,  0.5226],
#         [ 0.6159,  0.4688],
#         [ 0.4621, -0.1103]], requires_grad=True), Parameter containing:
# tensor([ 0.4609, -0.2402, -0.1706,  0.3753,  0.1589, -0.2866,  0.6609,  0.5754,
#         -0.1292,  0.0009], requires_grad=True), Parameter containing:
# tensor([[ 0.1683, -0.1365, -0.0784,  0.2941, -0.2895,  0.1490, -0.1864, -0.0484,
#          -0.2466,  0.2959],
#         [-0.1418, -0.0909,  0.2066, -0.2552, -0.0613,  0.2587,  0.0890, -0.0771,
#           0.1880, -0.1072]], requires_grad=True), Parameter containing:
# tensor([0.0966, 0.2382], requires_grad=True)]
#
# [Parameter containing:
# tensor([[ 0.6919,  0.5039],
#         [ 0.6346,  0.0946],
#         [ 0.3478, -0.3078],
#         [ 0.6189, -0.1504],
#         [-0.4179,  0.1919],
#         [-0.6641,  0.3204],
#         [-0.6598, -0.6413],
#         [-0.1408,  0.5228],
#         [ 0.6135,  0.4658],
#         [ 0.4642, -0.1079]], requires_grad=True), Parameter containing:
# tensor([ 0.4619, -0.2403, -0.1706,  0.3767,  0.1591, -0.2865,  0.6615,  0.5755,
#         -0.1306,  0.0020], requires_grad=True), Parameter containing:
# tensor([[ 0.1769, -0.1332, -0.0783,  0.2975, -0.2904,  0.1481, -0.1933, -0.0441,
#          -0.2405,  0.2977],
#         [-0.1504, -0.0942,  0.2065, -0.2587, -0.0604,  0.2596,  0.0959, -0.0815,
#           0.1819, -0.1090]], requires_grad=True), Parameter containing:
# tensor([0.0977, 0.2371], requires_grad=True)]
#
# [Parameter containing:
# tensor([[ 0.6935,  0.5059],
#         [ 0.6344,  0.0944],
#         [ 0.3470, -0.3086],
#         [ 0.6218, -0.1466],
#         [-0.4190,  0.1904],
#         [-0.6645,  0.3200],
#         [-0.6610, -0.6425],
#         [-0.1406,  0.5231],
#         [ 0.6115,  0.4632],
#         [ 0.4662, -0.1057]], requires_grad=True), Parameter containing:
# tensor([ 0.4628, -0.2404, -0.1706,  0.3781,  0.1592, -0.2864,  0.6620,  0.5756,
#         -0.1319,  0.0031], requires_grad=True), Parameter containing:
# tensor([[ 0.1849, -0.1302, -0.0781,  0.3006, -0.2913,  0.1472, -0.2000, -0.0401,
#          -0.2350,  0.2994],
#         [-0.1584, -0.0972,  0.2063, -0.2618, -0.0595,  0.2605,  0.1026, -0.0855,
#           0.1764, -0.1107]], requires_grad=True), Parameter containing:
# tensor([0.0986, 0.2362], requires_grad=True)]
#
# [Parameter containing:
# tensor([[ 0.6950,  0.5079],
#         [ 0.6343,  0.0942],
#         [ 0.3462, -0.3094],
#         [ 0.6245, -0.1431],
#         [-0.4201,  0.1889],
#         [-0.6649,  0.3196],
#         [-0.6622, -0.6437],
#         [-0.1403,  0.5234],
#         [ 0.6097,  0.4608],
#         [ 0.4680, -0.1037]], requires_grad=True), Parameter containing:
# tensor([ 0.4638, -0.2405, -0.1707,  0.3794,  0.1594, -0.2863,  0.6626,  0.5756,
#         -0.1331,  0.0041], requires_grad=True), Parameter containing:
# tensor([[ 0.1922, -0.1275, -0.0781,  0.3035, -0.2921,  0.1463, -0.2065, -0.0364,
#          -0.2299,  0.3009],
#         [-0.1657, -0.0999,  0.2063, -0.2647, -0.0586,  0.2614,  0.1090, -0.0892,
#           0.1714, -0.1122]], requires_grad=True), Parameter containing:
# tensor([0.0994, 0.2354], requires_grad=True)]
#
# [Parameter containing:
# tensor([[ 0.6965,  0.5099],
#         [ 0.6342,  0.0941],
#         [ 0.3455, -0.3101],
#         [ 0.6270, -0.1397],
#         [-0.4211,  0.1875],
#         [-0.6652,  0.3192],
#         [-0.6634, -0.6449],
#         [-0.1400,  0.5237],
#         [ 0.6081,  0.4586],
#         [ 0.4696, -0.1019]], requires_grad=True), Parameter containing:
# tensor([ 0.4647, -0.2406, -0.1707,  0.3806,  0.1596, -0.2862,  0.6632,  0.5757,
#         -0.1341,  0.0050], requires_grad=True), Parameter containing:
# tensor([[ 0.1989, -0.1250, -0.0780,  0.3061, -0.2930,  0.1455, -0.2127, -0.0329,
#          -0.2253,  0.3023],
#         [-0.1724, -0.1024,  0.2062, -0.2673, -0.0578,  0.2622,  0.1152, -0.0926,
#           0.1668, -0.1136]], requires_grad=True), Parameter containing:
# tensor([0.1000, 0.2347], requires_grad=True)]
#
# [Parameter containing:
# tensor([[ 0.6978,  0.5117],
#         [ 0.6341,  0.0940],
#         [ 0.3449, -0.3108],
#         [ 0.6293, -0.1365],
#         [-0.4221,  0.1862],
#         [-0.6656,  0.3188],
#         [-0.6646, -0.6461],
#         [-0.1397,  0.5240],
#         [ 0.6066,  0.4567],
#         [ 0.4712, -0.1001]], requires_grad=True), Parameter containing:
# tensor([ 0.4656, -0.2406, -0.1706,  0.3817,  0.1598, -0.2862,  0.6638,  0.5758,
#         -0.1351,  0.0059], requires_grad=True), Parameter containing:
# tensor([[ 0.2052, -0.1227, -0.0780,  0.3087, -0.2938,  0.1447, -0.2186, -0.0297,
#          -0.2211,  0.3036],
#         [-0.1787, -0.1047,  0.2062, -0.2698, -0.0569,  0.2630,  0.1212, -0.0958,
#           0.1625, -0.1150]], requires_grad=True), Parameter containing:
# tensor([0.1006, 0.2342], requires_grad=True)]
#
# [Parameter containing:
# tensor([[ 0.6992,  0.5135],
#         [ 0.6340,  0.0939],
#         [ 0.3442, -0.3115],
#         [ 0.6315, -0.1335],
#         [-0.4231,  0.1849],
#         [-0.6659,  0.3184],
#         [-0.6658, -0.6473],
#         [-0.1394,  0.5244],
#         [ 0.6053,  0.4548],
#         [ 0.4726, -0.0985]], requires_grad=True), Parameter containing:
# tensor([ 0.4665, -0.2407, -0.1706,  0.3828,  0.1599, -0.2861,  0.6644,  0.5760,
#         -0.1360,  0.0067], requires_grad=True), Parameter containing:
# tensor([[ 0.2111, -0.1206, -0.0779,  0.3110, -0.2946,  0.1440, -0.2244, -0.0267,
#          -0.2172,  0.3049],
#         [-0.1846, -0.1068,  0.2061, -0.2722, -0.0561,  0.2637,  0.1270, -0.0988,
#           0.1586, -0.1162]], requires_grad=True), Parameter containing:
# tensor([0.1010, 0.2337], requires_grad=True)]
#
# [Parameter containing:
# tensor([[ 0.7004,  0.5153],
#         [ 0.6340,  0.0938],
#         [ 0.3437, -0.3121],
#         [ 0.6335, -0.1306],
#         [-0.4240,  0.1836],
#         [-0.6663,  0.3181],
#         [-0.6670, -0.6485],
#         [-0.1390,  0.5247],
#         [ 0.6041,  0.4532],
#         [ 0.4739, -0.0970]], requires_grad=True), Parameter containing:
# tensor([ 0.4673, -0.2407, -0.1706,  0.3838,  0.1601, -0.2860,  0.6649,  0.5761,
#         -0.1368,  0.0075], requires_grad=True), Parameter containing:
# tensor([[ 0.2166, -0.1186, -0.0779,  0.3132, -0.2954,  0.1432, -0.2300, -0.0238,
#          -0.2135,  0.3060],
#         [-0.1901, -0.1087,  0.2061, -0.2744, -0.0553,  0.2645,  0.1325, -0.1017,
#           0.1549, -0.1173]], requires_grad=True), Parameter containing:
# tensor([0.1014, 0.2333], requires_grad=True)]
#
# [Parameter containing:
# tensor([[ 0.7016,  0.5170],
#         [ 0.6340,  0.0938],
#         [ 0.3431, -0.3127],
#         [ 0.6354, -0.1279],
#         [-0.4249,  0.1824],
#         [-0.6666,  0.3177],
#         [-0.6682, -0.6497],
#         [-0.1387,  0.5251],
#         [ 0.6030,  0.4516],
#         [ 0.4752, -0.0955]], requires_grad=True), Parameter containing:
# tensor([ 0.4682, -0.2407, -0.1705,  0.3847,  0.1603, -0.2859,  0.6655,  0.5762,
#         -0.1376,  0.0083], requires_grad=True), Parameter containing:
# tensor([[ 0.2218, -0.1168, -0.0779,  0.3153, -0.2962,  0.1425, -0.2354, -0.0212,
#          -0.2101,  0.3071],
#         [-0.1953, -0.1105,  0.2061, -0.2765, -0.0546,  0.2652,  0.1379, -0.1044,
#           0.1515, -0.1184]], requires_grad=True), Parameter containing:
# tensor([0.1018, 0.2330], requires_grad=True)]
#
# [Parameter containing:
# tensor([[ 0.7028,  0.5186],
#         [ 0.6339,  0.0938],
#         [ 0.3426, -0.3133],
#         [ 0.6372, -0.1253],
#         [-0.4258,  0.1812],
#         [-0.6669,  0.3174],
#         [-0.6694, -0.6509],
#         [-0.1383,  0.5255],
#         [ 0.6020,  0.4502],
#         [ 0.4764, -0.0942]], requires_grad=True), Parameter containing:
# tensor([ 0.4690, -0.2407, -0.1705,  0.3856,  0.1605, -0.2858,  0.6661,  0.5763,
#         -0.1383,  0.0090], requires_grad=True), Parameter containing:
# tensor([[ 0.2267, -0.1151, -0.0779,  0.3173, -0.2969,  0.1418, -0.2406, -0.0186,
#          -0.2069,  0.3081],
#         [-0.2002, -0.1122,  0.2061, -0.2784, -0.0538,  0.2659,  0.1431, -0.1069,
#           0.1483, -0.1194]], requires_grad=True), Parameter containing:
# tensor([0.1021, 0.2327], requires_grad=True)]
#
# [Parameter containing:
# tensor([[ 0.7039,  0.5202],
#         [ 0.6339,  0.0937],
#         [ 0.3421, -0.3139],
#         [ 0.6389, -0.1229],
#         [-0.4266,  0.1801],
#         [-0.6672,  0.3171],
#         [-0.6706, -0.6520],
#         [-0.1380,  0.5258],
#         [ 0.6011,  0.4489],
#         [ 0.4775, -0.0929]], requires_grad=True), Parameter containing:
# tensor([ 0.4698, -0.2407, -0.1704,  0.3865,  0.1606, -0.2858,  0.6667,  0.5764,
#         -0.1390,  0.0096], requires_grad=True), Parameter containing:
# tensor([[ 0.2314, -0.1135, -0.0779,  0.3191, -0.2977,  0.1412, -0.2456, -0.0162,
#          -0.2039,  0.3091],
#         [-0.2049, -0.1138,  0.2061, -0.2803, -0.0531,  0.2665,  0.1482, -0.1093,
#           0.1453, -0.1204]], requires_grad=True), Parameter containing:
# tensor([0.1023, 0.2324], requires_grad=True)]
#
# [Parameter containing:
# tensor([[ 0.7050,  0.5218],
#         [ 0.6339,  0.0938],
#         [ 0.3416, -0.3145],
#         [ 0.6405, -0.1205],
#         [-0.4275,  0.1790],
#         [-0.6676,  0.3168],
#         [-0.6718, -0.6532],
#         [-0.1376,  0.5262],
#         [ 0.6002,  0.4476],
#         [ 0.4785, -0.0917]], requires_grad=True), Parameter containing:
# tensor([ 0.4705, -0.2407, -0.1704,  0.3873,  0.1608, -0.2857,  0.6672,  0.5765,
#         -0.1396,  0.0103], requires_grad=True), Parameter containing:
# tensor([[ 0.2358, -0.1120, -0.0779,  0.3209, -0.2984,  0.1405, -0.2505, -0.0139,
#          -0.2011,  0.3100],
#         [-0.2093, -0.1153,  0.2061, -0.2821, -0.0523,  0.2672,  0.1531, -0.1116,
#           0.1425, -0.1213]], requires_grad=True), Parameter containing:
# tensor([0.1025, 0.2322], requires_grad=True)]
#
# [Parameter containing:
# tensor([[ 0.7061,  0.5233],
#         [ 0.6339,  0.0938],
#         [ 0.3411, -0.3150],
#         [ 0.6421, -0.1183],
#         [-0.4283,  0.1779],
#         [-0.6679,  0.3164],
#         [-0.6729, -0.6544],
#         [-0.1373,  0.5266],
#         [ 0.5994,  0.4465],
#         [ 0.4795, -0.0906]], requires_grad=True), Parameter containing:
# tensor([ 0.4713, -0.2407, -0.1703,  0.3881,  0.1610, -0.2856,  0.6678,  0.5766,
#         -0.1402,  0.0109], requires_grad=True), Parameter containing:
# tensor([[ 0.2400, -0.1106, -0.0779,  0.3226, -0.2991,  0.1399, -0.2553, -0.0117,
#          -0.1984,  0.3109],
#         [-0.2135, -0.1167,  0.2061, -0.2838, -0.0516,  0.2678,  0.1578, -0.1138,
#           0.1398, -0.1222]], requires_grad=True), Parameter containing:
# tensor([0.1027, 0.2320], requires_grad=True)]
#
# [Parameter containing:
# tensor([[ 0.7071,  0.5248],
#         [ 0.6340,  0.0938],
#         [ 0.3407, -0.3156],
#         [ 0.6436, -0.1161],
#         [-0.4291,  0.1768],
#         [-0.6681,  0.3161],
#         [-0.6741, -0.6555],
#         [-0.1370,  0.5270],
#         [ 0.5987,  0.4454],
#         [ 0.4805, -0.0895]], requires_grad=True), Parameter containing:
# tensor([ 0.4720, -0.2407, -0.1702,  0.3889,  0.1611, -0.2855,  0.6684,  0.5767,
#         -0.1407,  0.0115], requires_grad=True), Parameter containing:
# tensor([[ 0.2440, -0.1093, -0.0780,  0.3242, -0.2998,  0.1393, -0.2599, -0.0096,
#          -0.1959,  0.3117],
#         [-0.2175, -0.1181,  0.2061, -0.2854, -0.0509,  0.2684,  0.1624, -0.1159,
#           0.1373, -0.1230]], requires_grad=True), Parameter containing:
# tensor([0.1029, 0.2319], requires_grad=True)]
#
# [Parameter containing:
# tensor([[ 0.7080,  0.5262],
#         [ 0.6340,  0.0938],
#         [ 0.3403, -0.3161],
#         [ 0.6450, -0.1139],
#         [-0.4298,  0.1758],
#         [-0.6684,  0.3158],
#         [-0.6752, -0.6566],
#         [-0.1366,  0.5273],
#         [ 0.5980,  0.4443],
#         [ 0.4814, -0.0884]], requires_grad=True), Parameter containing:
# tensor([ 0.4727, -0.2407, -0.1702,  0.3896,  0.1613, -0.2854,  0.6689,  0.5768,
#         -0.1413,  0.0121], requires_grad=True), Parameter containing:
# tensor([[ 0.2478, -0.1080, -0.0780,  0.3258, -0.3005,  0.1387, -0.2644, -0.0076,
#          -0.1935,  0.3125],
#         [-0.2213, -0.1193,  0.2062, -0.2870, -0.0502,  0.2690,  0.1669, -0.1179,
#           0.1349, -0.1238]], requires_grad=True), Parameter containing:
# tensor([0.1030, 0.2318], requires_grad=True)]
#
# [Parameter containing:
# tensor([[ 0.7090,  0.5276],
#         [ 0.6340,  0.0938],
#         [ 0.3399, -0.3166],
#         [ 0.6463, -0.1118],
#         [-0.4305,  0.1748],
#         [-0.6687,  0.3156],
#         [-0.6763, -0.6578],
#         [-0.1363,  0.5277],
#         [ 0.5973,  0.4433],
#         [ 0.4822, -0.0874]], requires_grad=True), Parameter containing:
# tensor([ 0.4734, -0.2407, -0.1701,  0.3904,  0.1615, -0.2854,  0.6695,  0.5770,
#         -0.1418,  0.0126], requires_grad=True), Parameter containing:
# tensor([[ 0.2515, -0.1068, -0.0780,  0.3273, -0.3012,  0.1381, -0.2687, -0.0057,
#          -0.1912,  0.3133],
#         [-0.2250, -0.1205,  0.2062, -0.2885, -0.0496,  0.2696,  0.1713, -0.1198,
#           0.1326, -0.1246]], requires_grad=True), Parameter containing:
# tensor([0.1031, 0.2317], requires_grad=True)]
#
# [Parameter containing:
# tensor([[ 0.7099,  0.5290],
#         [ 0.6340,  0.0939],
#         [ 0.3395, -0.3171],
#         [ 0.6476, -0.1098],
#         [-0.4313,  0.1739],
#         [-0.6690,  0.3153],
#         [-0.6775, -0.6589],
#         [-0.1359,  0.5281],
#         [ 0.5967,  0.4424],
#         [ 0.4830, -0.0864]], requires_grad=True), Parameter containing:
# tensor([ 0.4741, -0.2407, -0.1700,  0.3911,  0.1616, -0.2853,  0.6700,  0.5771,
#         -0.1422,  0.0132], requires_grad=True), Parameter containing:
# tensor([[ 0.2550, -0.1057, -0.0780,  0.3287, -0.3018,  0.1375, -0.2729, -0.0039,
#          -0.1890,  0.3140],
#         [-0.2285, -0.1217,  0.2062, -0.2899, -0.0489,  0.2702,  0.1755, -0.1217,
#           0.1304, -0.1253]], requires_grad=True), Parameter containing:
# tensor([0.1032, 0.2316], requires_grad=True)]
#
# [Parameter containing:
# tensor([[ 0.7108,  0.5303],
#         [ 0.6341,  0.0939],
#         [ 0.3391, -0.3175],
#         [ 0.6489, -0.1079],
#         [-0.4320,  0.1729],
#         [-0.6693,  0.3150],
#         [-0.6786, -0.6600],
#         [-0.1356,  0.5284],
#         [ 0.5961,  0.4415],
#         [ 0.4838, -0.0855]], requires_grad=True), Parameter containing:
# tensor([ 0.4747, -0.2406, -0.1700,  0.3917,  0.1618, -0.2852,  0.6706,  0.5772,
#         -0.1427,  0.0137], requires_grad=True), Parameter containing:
# tensor([[ 0.2584, -0.1046, -0.0781,  0.3301, -0.3025,  0.1370, -0.2771, -0.0021,
#          -0.1869,  0.3147],
#         [-0.2319, -0.1228,  0.2063, -0.2913, -0.0483,  0.2707,  0.1796, -0.1234,
#           0.1283, -0.1260]], requires_grad=True), Parameter containing:
# tensor([0.1033, 0.2315], requires_grad=True)]
#
# [Parameter containing:
# tensor([[ 0.7116,  0.5316],
#         [ 0.6341,  0.0940],
#         [ 0.3388, -0.3180],
#         [ 0.6501, -0.1060],
#         [-0.4326,  0.1720],
#         [-0.6695,  0.3147],
#         [-0.6797, -0.6611],
#         [-0.1352,  0.5288],
#         [ 0.5956,  0.4407],
#         [ 0.4846, -0.0846]], requires_grad=True), Parameter containing:
# tensor([ 0.4754, -0.2406, -0.1699,  0.3924,  0.1619, -0.2851,  0.6711,  0.5773,
#         -0.1431,  0.0142], requires_grad=True), Parameter containing:
# tensor([[ 0.2617, -0.1035, -0.0781,  0.3314, -0.3031,  0.1365, -0.2811, -0.0004,
#          -0.1849,  0.3154],
#         [-0.2352, -0.1238,  0.2063, -0.2926, -0.0476,  0.2712,  0.1836, -0.1252,
#           0.1263, -0.1267]], requires_grad=True), Parameter containing:
# tensor([0.1033, 0.2314], requires_grad=True)]
#
# [Parameter containing:
# tensor([[ 0.7124,  0.5329],
#         [ 0.6341,  0.0940],
#         [ 0.3384, -0.3184],
#         [ 0.6512, -0.1041],
#         [-0.4333,  0.1711],
#         [-0.6698,  0.3145],
#         [-0.6808, -0.6622],
#         [-0.1349,  0.5292],
#         [ 0.5951,  0.4399],
#         [ 0.4853, -0.0838]], requires_grad=True), Parameter containing:
# tensor([ 0.4760, -0.2406, -0.1698,  0.3930,  0.1621, -0.2851,  0.6717,  0.5774,
#         -0.1435,  0.0146], requires_grad=True), Parameter containing:
# tensor([[ 0.2649, -0.1025, -0.0781,  0.3327, -0.3037,  0.1360, -0.2850,  0.0013,
#          -0.1830,  0.3160],
#         [-0.2384, -0.1248,  0.2063, -0.2939, -0.0470,  0.2717,  0.1875, -0.1268,
#           0.1244, -0.1273]], requires_grad=True), Parameter containing:
# tensor([0.1034, 0.2314], requires_grad=True)]
#
# [Parameter containing:
# tensor([[ 0.7132,  0.5341],
#         [ 0.6342,  0.0941],
#         [ 0.3381, -0.3188],
#         [ 0.6523, -0.1024],
#         [-0.4339,  0.1703],
#         [-0.6700,  0.3142],
#         [-0.6818, -0.6633],
#         [-0.1346,  0.5295],
#         [ 0.5946,  0.4392],
#         [ 0.4860, -0.0829]], requires_grad=True), Parameter containing:
# tensor([ 0.4767, -0.2406, -0.1697,  0.3937,  0.1623, -0.2850,  0.6722,  0.5775,
#         -0.1439,  0.0151], requires_grad=True), Parameter containing:
# tensor([[ 0.2679, -0.1016, -0.0782,  0.3340, -0.3043,  0.1355, -0.2888,  0.0029,
#          -0.1812,  0.3166],
#         [-0.2414, -0.1258,  0.2064, -0.2952, -0.0464,  0.2722,  0.1913, -0.1284,
#           0.1226, -0.1279]], requires_grad=True), Parameter containing:
# tensor([0.1034, 0.2313], requires_grad=True)]
#
# [Parameter containing:
# tensor([[ 0.7140,  0.5353],
#         [ 0.6342,  0.0941],
#         [ 0.3378, -0.3192],
#         [ 0.6534, -0.1006],
#         [-0.4346,  0.1694],
#         [-0.6703,  0.3139],
#         [-0.6829, -0.6643],
#         [-0.1343,  0.5299],
#         [ 0.5941,  0.4384],
#         [ 0.4867, -0.0822]], requires_grad=True), Parameter containing:
# tensor([ 0.4773, -0.2406, -0.1697,  0.3943,  0.1624, -0.2849,  0.6727,  0.5776,
#         -0.1443,  0.0155], requires_grad=True), Parameter containing:
# tensor([[ 0.2708, -0.1006, -0.0782,  0.3352, -0.3049,  0.1350, -0.2925,  0.0044,
#          -0.1794,  0.3172],
#         [-0.2443, -0.1267,  0.2064, -0.2964, -0.0458,  0.2727,  0.1950, -0.1300,
#           0.1208, -0.1285]], requires_grad=True), Parameter containing:
# tensor([0.1034, 0.2313], requires_grad=True)]
#
# [Parameter containing:
# tensor([[ 0.7148,  0.5365],
#         [ 0.6342,  0.0942],
#         [ 0.3375, -0.3196],
#         [ 0.6544, -0.0990],
#         [-0.4352,  0.1686],
#         [-0.6705,  0.3137],
#         [-0.6839, -0.6654],
#         [-0.1339,  0.5302],
#         [ 0.5937,  0.4377],
#         [ 0.4873, -0.0814]], requires_grad=True), Parameter containing:
# tensor([ 0.4779, -0.2405, -0.1696,  0.3949,  0.1626, -0.2849,  0.6732,  0.5777,
#         -0.1447,  0.0160], requires_grad=True), Parameter containing:
# tensor([[ 0.2737, -0.0997, -0.0782,  0.3364, -0.3055,  0.1345, -0.2961,  0.0059,
#          -0.1777,  0.3178],
#         [-0.2472, -0.1276,  0.2064, -0.2976, -0.0452,  0.2732,  0.1986, -0.1315,
#           0.1191, -0.1291]], requires_grad=True), Parameter containing:
# tensor([0.1034, 0.2313], requires_grad=True)]
#
# [Parameter containing:
# tensor([[ 0.7155,  0.5376],
#         [ 0.6343,  0.0942],
#         [ 0.3372, -0.3200],
#         [ 0.6554, -0.0974],
#         [-0.4358,  0.1677],
#         [-0.6708,  0.3135],
#         [-0.6850, -0.6664],
#         [-0.1336,  0.5306],
#         [ 0.5933,  0.4371],
#         [ 0.4879, -0.0806]], requires_grad=True), Parameter containing:
# tensor([ 0.4785, -0.2405, -0.1695,  0.3954,  0.1627, -0.2848,  0.6737,  0.5778,
#         -0.1450,  0.0164], requires_grad=True), Parameter containing:
# tensor([[ 0.2764, -0.0989, -0.0783,  0.3375, -0.3061,  0.1340, -0.2996,  0.0074,
#          -0.1761,  0.3184],
#         [-0.2499, -0.1285,  0.2065, -0.2987, -0.0447,  0.2737,  0.2022, -0.1329,
#           0.1175, -0.1297]], requires_grad=True), Parameter containing:
# tensor([0.1035, 0.2313], requires_grad=True)]
#
# [Parameter containing:
# tensor([[ 0.7163,  0.5388],
#         [ 0.6343,  0.0943],
#         [ 0.3369, -0.3204],
#         [ 0.6564, -0.0958],
#         [-0.4364,  0.1669],
#         [-0.6710,  0.3132],
#         [-0.6860, -0.6674],
#         [-0.1333,  0.5309],
#         [ 0.5929,  0.4364],
#         [ 0.4885, -0.0799]], requires_grad=True), Parameter containing:
# tensor([ 0.4791, -0.2405, -0.1695,  0.3960,  0.1629, -0.2847,  0.6743,  0.5779,
#         -0.1453,  0.0168], requires_grad=True), Parameter containing:
# tensor([[ 0.2791, -0.0981, -0.0783,  0.3386, -0.3066,  0.1336, -0.3031,  0.0088,
#          -0.1745,  0.3189],
#         [-0.2526, -0.1293,  0.2065, -0.2998, -0.0441,  0.2741,  0.2056, -0.1343,
#           0.1159, -0.1302]], requires_grad=True), Parameter containing:
# tensor([0.1035, 0.2313], requires_grad=True)]
#
# [Parameter containing:
# tensor([[ 0.7170,  0.5399],
#         [ 0.6343,  0.0944],
#         [ 0.3366, -0.3207],
#         [ 0.6573, -0.0943],
#         [-0.4370,  0.1661],
#         [-0.6712,  0.3130],
#         [-0.6870, -0.6684],
#         [-0.1330,  0.5313],
#         [ 0.5925,  0.4358],
#         [ 0.4891, -0.0792]], requires_grad=True), Parameter containing:
# tensor([ 0.4796, -0.2404, -0.1694,  0.3965,  0.1630, -0.2847,  0.6748,  0.5780,
#         -0.1457,  0.0172], requires_grad=True), Parameter containing:
# tensor([[ 0.2817, -0.0973, -0.0784,  0.3397, -0.3072,  0.1331, -0.3064,  0.0102,
#          -0.1729,  0.3194],
#         [-0.2552, -0.1301,  0.2066, -0.3009, -0.0436,  0.2746,  0.2090, -0.1357,
#           0.1143, -0.1308]], requires_grad=True), Parameter containing:
# tensor([0.1035, 0.2313], requires_grad=True)]
#
# [Parameter containing:
# tensor([[ 0.7176,  0.5410],
#         [ 0.6344,  0.0944],
#         [ 0.3363, -0.3211],
#         [ 0.6582, -0.0928],
#         [-0.4375,  0.1653],
#         [-0.6714,  0.3127],
#         [-0.6880, -0.6694],
#         [-0.1327,  0.5316],
#         [ 0.5921,  0.4352],
#         [ 0.4897, -0.0785]], requires_grad=True), Parameter containing:
# tensor([ 0.4802, -0.2404, -0.1693,  0.3971,  0.1632, -0.2846,  0.6753,  0.5781,
#         -0.1460,  0.0176], requires_grad=True), Parameter containing:
# tensor([[ 0.2842, -0.0965, -0.0784,  0.3407, -0.3077,  0.1327, -0.3097,  0.0115,
#          -0.1715,  0.3199],
#         [-0.2577, -0.1309,  0.2066, -0.3019, -0.0430,  0.2750,  0.2123, -0.1370,
#           0.1129, -0.1313]], requires_grad=True), Parameter containing:
# tensor([0.1035, 0.2313], requires_grad=True)]
#
# [Parameter containing:
# tensor([[ 0.7183,  0.5420],
#         [ 0.6344,  0.0945],
#         [ 0.3361, -0.3215],
#         [ 0.6591, -0.0914],
#         [-0.4381,  0.1646],
#         [-0.6717,  0.3125],
#         [-0.6890, -0.6704],
#         [-0.1324,  0.5320],
#         [ 0.5918,  0.4347],
#         [ 0.4902, -0.0779]], requires_grad=True), Parameter containing:
# tensor([ 0.4807, -0.2404, -0.1693,  0.3976,  0.1633, -0.2846,  0.6758,  0.5782,
#         -0.1463,  0.0180], requires_grad=True), Parameter containing:
# tensor([[ 0.2867, -0.0958, -0.0784,  0.3417, -0.3083,  0.1323, -0.3129,  0.0128,
#          -0.1700,  0.3204],
#         [-0.2602, -0.1316,  0.2066, -0.3029, -0.0425,  0.2754,  0.2155, -0.1383,
#           0.1114, -0.1318]], requires_grad=True), Parameter containing:
# tensor([0.1035, 0.2313], requires_grad=True)]
#
# [Parameter containing:
# tensor([[ 0.7190,  0.5431],
#         [ 0.6345,  0.0945],
#         [ 0.3358, -0.3218],
#         [ 0.6600, -0.0900],
#         [-0.4386,  0.1638],
#         [-0.6719,  0.3123],
#         [-0.6900, -0.6714],
#         [-0.1321,  0.5323],
#         [ 0.5915,  0.4341],
#         [ 0.4908, -0.0772]], requires_grad=True), Parameter containing:
# tensor([ 0.4813, -0.2403, -0.1692,  0.3981,  0.1634, -0.2845,  0.6763,  0.5783,
#         -0.1466,  0.0184], requires_grad=True), Parameter containing:
# tensor([[ 0.2890, -0.0950, -0.0785,  0.3427, -0.3088,  0.1319, -0.3161,  0.0141,
#          -0.1686,  0.3209],
#         [-0.2625, -0.1323,  0.2067, -0.3039, -0.0420,  0.2758,  0.2186, -0.1396,
#           0.1101, -0.1322]], requires_grad=True), Parameter containing:
# tensor([0.1034, 0.2313], requires_grad=True)]
#
# [Parameter containing:
# tensor([[ 0.7196,  0.5441],
#         [ 0.6345,  0.0946],
#         [ 0.3355, -0.3221],
#         [ 0.6608, -0.0886],
#         [-0.4392,  0.1631],
#         [-0.6721,  0.3121],
#         [-0.6910, -0.6723],
#         [-0.1318,  0.5326],
#         [ 0.5911,  0.4336],
#         [ 0.4913, -0.0766]], requires_grad=True), Parameter containing:
# tensor([ 0.4818, -0.2403, -0.1691,  0.3986,  0.1636, -0.2844,  0.6768,  0.5784,
#         -0.1469,  0.0187], requires_grad=True), Parameter containing:
# tensor([[ 0.2914, -0.0944, -0.0785,  0.3437, -0.3093,  0.1315, -0.3192,  0.0153,
#          -0.1673,  0.3214],
#         [-0.2649, -0.1330,  0.2067, -0.3049, -0.0415,  0.2762,  0.2217, -0.1408,
#           0.1087, -0.1327]], requires_grad=True), Parameter containing:
# tensor([0.1034, 0.2313], requires_grad=True)]
#
# [Parameter containing:
# tensor([[ 0.7202,  0.5451],
#         [ 0.6346,  0.0947],
#         [ 0.3353, -0.3225],
#         [ 0.6616, -0.0873],
#         [-0.4397,  0.1624],
#         [-0.6723,  0.3119],
#         [-0.6919, -0.6732],
#         [-0.1315,  0.5329],
#         [ 0.5908,  0.4331],
#         [ 0.4918, -0.0760]], requires_grad=True), Parameter containing:
# tensor([ 0.4823, -0.2403, -0.1691,  0.3991,  0.1637, -0.2844,  0.6773,  0.5785,
#         -0.1471,  0.0191], requires_grad=True), Parameter containing:
# tensor([[ 0.2936, -0.0937, -0.0786,  0.3446, -0.3098,  0.1311, -0.3222,  0.0165,
#          -0.1660,  0.3218],
#         [-0.2671, -0.1337,  0.2068, -0.3058, -0.0410,  0.2766,  0.2247, -0.1420,
#           0.1074, -0.1332]], requires_grad=True), Parameter containing:
# tensor([0.1034, 0.2313], requires_grad=True)]
#
# [Parameter containing:
# tensor([[ 0.7209,  0.5461],
#         [ 0.6346,  0.0947],
#         [ 0.3351, -0.3228],
#         [ 0.6624, -0.0860],
#         [-0.4402,  0.1617],
#         [-0.6725,  0.3116],
#         [-0.6929, -0.6742],
#         [-0.1312,  0.5333],
#         [ 0.5905,  0.4326],
#         [ 0.4923, -0.0754]], requires_grad=True), Parameter containing:
# tensor([ 0.4829, -0.2402, -0.1690,  0.3996,  0.1639, -0.2843,  0.6778,  0.5785,
#         -0.1474,  0.0194], requires_grad=True), Parameter containing:
# tensor([[ 0.2958, -0.0930, -0.0786,  0.3456, -0.3103,  0.1307, -0.3252,  0.0177,
#          -0.1647,  0.3223],
#         [-0.2693, -0.1343,  0.2068, -0.3068, -0.0405,  0.2770,  0.2277, -0.1432,
#           0.1061, -0.1336]], requires_grad=True), Parameter containing:
# tensor([0.1034, 0.2313], requires_grad=True)]
#
# [Parameter containing:
# tensor([[ 0.7215,  0.5471],
#         [ 0.6346,  0.0948],
#         [ 0.3348, -0.3231],
#         [ 0.6631, -0.0847],
#         [-0.4407,  0.1610],
#         [-0.6727,  0.3114],
#         [-0.6938, -0.6751],
#         [-0.1309,  0.5336],
#         [ 0.5903,  0.4322],
#         [ 0.4927, -0.0749]], requires_grad=True), Parameter containing:
# tensor([ 0.4834, -0.2402, -0.1689,  0.4001,  0.1640, -0.2843,  0.6783,  0.5786,
#         -0.1476,  0.0198], requires_grad=True), Parameter containing:
# tensor([[ 0.2980, -0.0924, -0.0786,  0.3465, -0.3108,  0.1303, -0.3280,  0.0189,
#          -0.1635,  0.3227],
#         [-0.2715, -0.1350,  0.2068, -0.3077, -0.0400,  0.2774,  0.2306, -0.1444,
#           0.1049, -0.1340]], requires_grad=True), Parameter containing:
# tensor([0.1034, 0.2314], requires_grad=True)]
#
# [Parameter containing:
# tensor([[ 0.7220,  0.5481],
#         [ 0.6347,  0.0949],
#         [ 0.3346, -0.3234],
#         [ 0.6639, -0.0834],
#         [-0.4412,  0.1603],
#         [-0.6729,  0.3112],
#         [-0.6948, -0.6760],
#         [-0.1306,  0.5339],
#         [ 0.5900,  0.4317],
#         [ 0.4932, -0.0743]], requires_grad=True), Parameter containing:
# tensor([ 0.4839, -0.2402, -0.1689,  0.4006,  0.1641, -0.2842,  0.6788,  0.5787,
#         -0.1479,  0.0201], requires_grad=True), Parameter containing:
# tensor([[ 0.3001, -0.0918, -0.0787,  0.3473, -0.3113,  0.1299, -0.3309,  0.0200,
#          -0.1623,  0.3231],
#         [-0.2736, -0.1356,  0.2069, -0.3085, -0.0395,  0.2777,  0.2334, -0.1455,
#           0.1037, -0.1345]], requires_grad=True), Parameter containing:
# tensor([0.1034, 0.2314], requires_grad=True)]
#
# [Parameter containing:
# tensor([[ 0.7226,  0.5490],
#         [ 0.6347,  0.0949],
#         [ 0.3344, -0.3237],
#         [ 0.6646, -0.0822],
#         [-0.4417,  0.1596],
#         [-0.6731,  0.3110],
#         [-0.6957, -0.6769],
#         [-0.1303,  0.5342],
#         [ 0.5897,  0.4313],
#         [ 0.4937, -0.0737]], requires_grad=True), Parameter containing:
# tensor([ 0.4844, -0.2402, -0.1688,  0.4011,  0.1642, -0.2841,  0.6792,  0.5788,
#         -0.1481,  0.0204], requires_grad=True), Parameter containing:
# tensor([[ 0.3021, -0.0912, -0.0787,  0.3482, -0.3117,  0.1296, -0.3337,  0.0211,
#          -0.1611,  0.3235],
#         [-0.2756, -0.1362,  0.2069, -0.3094, -0.0390,  0.2781,  0.2362, -0.1466,
#           0.1025, -0.1349]], requires_grad=True), Parameter containing:
# tensor([0.1033, 0.2314], requires_grad=True)]
#
# [Parameter containing:
# tensor([[ 0.7232,  0.5500],
#         [ 0.6348,  0.0950],
#         [ 0.3342, -0.3240],
#         [ 0.6653, -0.0810],
#         [-0.4422,  0.1589],
#         [-0.6733,  0.3108],
#         [-0.6966, -0.6777],
#         [-0.1300,  0.5345],
#         [ 0.5895,  0.4308],
#         [ 0.4941, -0.0732]], requires_grad=True), Parameter containing:
# tensor([ 0.4849, -0.2401, -0.1688,  0.4015,  0.1644, -0.2841,  0.6797,  0.5789,
#         -0.1484,  0.0208], requires_grad=True), Parameter containing:
# tensor([[ 0.3041, -0.0906, -0.0788,  0.3490, -0.3122,  0.1292, -0.3364,  0.0221,
#          -0.1600,  0.3239],
#         [-0.2776, -0.1368,  0.2070, -0.3102, -0.0386,  0.2785,  0.2390, -0.1477,
#           0.1014, -0.1353]], requires_grad=True), Parameter containing:
# tensor([0.1033, 0.2314], requires_grad=True)]
#
# [Parameter containing:
# tensor([[ 0.7237,  0.5509],
#         [ 0.6348,  0.0951],
#         [ 0.3340, -0.3243],
#         [ 0.6660, -0.0798],
#         [-0.4426,  0.1583],
#         [-0.6735,  0.3106],
#         [-0.6975, -0.6786],
#         [-0.1297,  0.5348],
#         [ 0.5892,  0.4304],
#         [ 0.4945, -0.0727]], requires_grad=True), Parameter containing:
# tensor([ 0.4853, -0.2401, -0.1687,  0.4020,  0.1645, -0.2840,  0.6802,  0.5790,
#         -0.1486,  0.0211], requires_grad=True), Parameter containing:
# tensor([[ 0.3061, -0.0900, -0.0788,  0.3499, -0.3126,  0.1289, -0.3391,  0.0232,
#          -0.1589,  0.3243],
#         [-0.2796, -0.1373,  0.2070, -0.3111, -0.0381,  0.2788,  0.2416, -0.1487,
#           0.1003, -0.1357]], requires_grad=True), Parameter containing:
# tensor([0.1033, 0.2315], requires_grad=True)]
#
# [Parameter containing:
# tensor([[ 0.7243,  0.5518],
#         [ 0.6349,  0.0951],
#         [ 0.3338, -0.3246],
#         [ 0.6666, -0.0786],
#         [-0.4431,  0.1577],
#         [-0.6737,  0.3104],
#         [-0.6984, -0.6795],
#         [-0.1295,  0.5351],
#         [ 0.5890,  0.4300],
#         [ 0.4949, -0.0722]], requires_grad=True), Parameter containing:
# tensor([ 0.4858, -0.2401, -0.1686,  0.4025,  0.1646, -0.2840,  0.6807,  0.5791,
#         -0.1488,  0.0214], requires_grad=True), Parameter containing:
# tensor([[ 0.3080, -0.0895, -0.0789,  0.3507, -0.3131,  0.1285, -0.3417,  0.0242,
#          -0.1578,  0.3247],
#         [-0.2815, -0.1379,  0.2071, -0.3119, -0.0377,  0.2792,  0.2443, -0.1497,
#           0.0992, -0.1360]], requires_grad=True), Parameter containing:
# tensor([0.1033, 0.2315], requires_grad=True)]
#
# [Parameter containing:
# tensor([[ 0.7248,  0.5527],
#         [ 0.6349,  0.0952],
#         [ 0.3335, -0.3248],
#         [ 0.6673, -0.0774],
#         [-0.4435,  0.1570],
#         [-0.6739,  0.3102],
#         [-0.6993, -0.6803],
#         [-0.1292,  0.5354],
#         [ 0.5888,  0.4296],
#         [ 0.4954, -0.0716]], requires_grad=True), Parameter containing:
# tensor([ 0.4863, -0.2400, -0.1686,  0.4029,  0.1647, -0.2839,  0.6811,  0.5792,
#         -0.1490,  0.0217], requires_grad=True), Parameter containing:
# tensor([[ 0.3099, -0.0889, -0.0789,  0.3515, -0.3135,  0.1282, -0.3443,  0.0252,
#          -0.1568,  0.3251],
#         [-0.2834, -0.1384,  0.2071, -0.3127, -0.0372,  0.2795,  0.2468, -0.1507,
#           0.0982, -0.1364]], requires_grad=True), Parameter containing:
# tensor([0.1032, 0.2315], requires_grad=True)]
#
# [Parameter containing:
# tensor([[ 0.7253,  0.5535],
#         [ 0.6350,  0.0953],
#         [ 0.3333, -0.3251],
#         [ 0.6679, -0.0763],
#         [-0.4440,  0.1564],
#         [-0.6741,  0.3101],
#         [-0.7002, -0.6812],
#         [-0.1289,  0.5357],
#         [ 0.5885,  0.4293],
#         [ 0.4958, -0.0711]], requires_grad=True), Parameter containing:
# tensor([ 0.4867, -0.2400, -0.1685,  0.4033,  0.1648, -0.2839,  0.6816,  0.5792,
#         -0.1492,  0.0220], requires_grad=True), Parameter containing:
# tensor([[ 0.3117, -0.0884, -0.0789,  0.3522, -0.3140,  0.1279, -0.3468,  0.0262,
#          -0.1558,  0.3255],
#         [-0.2852, -0.1389,  0.2071, -0.3134, -0.0368,  0.2798,  0.2494, -0.1517,
#           0.0972, -0.1368]], requires_grad=True), Parameter containing:
# tensor([0.1032, 0.2315], requires_grad=True)]
#
# [Parameter containing:
# tensor([[ 0.7259,  0.5544],
#         [ 0.6350,  0.0953],
#         [ 0.3332, -0.3254],
#         [ 0.6686, -0.0752],
#         [-0.4444,  0.1558],
#         [-0.6742,  0.3099],
#         [-0.7011, -0.6820],
#         [-0.1286,  0.5360],
#         [ 0.5883,  0.4289],
#         [ 0.4961, -0.0706]], requires_grad=True), Parameter containing:
# tensor([ 0.4872, -0.2400, -0.1685,  0.4038,  0.1649, -0.2838,  0.6820,  0.5793,
#         -0.1494,  0.0223], requires_grad=True), Parameter containing:
# tensor([[ 0.3135, -0.0879, -0.0790,  0.3530, -0.3144,  0.1276, -0.3493,  0.0272,
#          -0.1548,  0.3258],
#         [-0.2870, -0.1395,  0.2072, -0.3142, -0.0364,  0.2801,  0.2519, -0.1527,
#           0.0962, -0.1371]], requires_grad=True), Parameter containing:
# tensor([0.1032, 0.2316], requires_grad=True)]
#
# [Parameter containing:
# tensor([[ 0.7264,  0.5552],
#         [ 0.6350,  0.0954],
#         [ 0.3330, -0.3256],
#         [ 0.6692, -0.0741],
#         [-0.4449,  0.1552],
#         [-0.6744,  0.3097],
#         [-0.7019, -0.6828],
#         [-0.1284,  0.5363],
#         [ 0.5881,  0.4285],
#         [ 0.4965, -0.0701]], requires_grad=True), Parameter containing:
# tensor([ 0.4877, -0.2399, -0.1684,  0.4042,  0.1651, -0.2838,  0.6825,  0.5794,
#         -0.1496,  0.0226], requires_grad=True), Parameter containing:
# tensor([[ 0.3153, -0.0874, -0.0790,  0.3537, -0.3148,  0.1272, -0.3517,  0.0281,
#          -0.1538,  0.3262],
#         [-0.2888, -0.1400,  0.2072, -0.3149, -0.0359,  0.2805,  0.2543, -0.1536,
#           0.0952, -0.1375]], requires_grad=True), Parameter containing:
# tensor([0.1031, 0.2316], requires_grad=True)]
#
# [Parameter containing:
# tensor([[ 0.7269,  0.5561],
#         [ 0.6351,  0.0955],
#         [ 0.3328, -0.3259],
#         [ 0.6698, -0.0730],
#         [-0.4453,  0.1546],
#         [-0.6746,  0.3095],
#         [-0.7028, -0.6836],
#         [-0.1281,  0.5366],
#         [ 0.5879,  0.4282],
#         [ 0.4969, -0.0697]], requires_grad=True), Parameter containing:
# tensor([ 0.4881, -0.2399, -0.1683,  0.4046,  0.1652, -0.2837,  0.6829,  0.5795,
#         -0.1498,  0.0229], requires_grad=True), Parameter containing:
# tensor([[ 0.3170, -0.0869, -0.0791,  0.3545, -0.3152,  0.1269, -0.3541,  0.0291,
#          -0.1528,  0.3265],
#         [-0.2905, -0.1404,  0.2073, -0.3157, -0.0355,  0.2808,  0.2567, -0.1546,
#           0.0942, -0.1378]], requires_grad=True), Parameter containing:
# tensor([0.1031, 0.2316], requires_grad=True)]
#
# [Parameter containing:
# tensor([[ 0.7273,  0.5569],
#         [ 0.6351,  0.0955],
#         [ 0.3326, -0.3261],
#         [ 0.6704, -0.0720],
#         [-0.4457,  0.1540],
#         [-0.6748,  0.3093],
#         [-0.7036, -0.6844],
#         [-0.1279,  0.5369],
#         [ 0.5877,  0.4278],
#         [ 0.4973, -0.0692]], requires_grad=True), Parameter containing:
# tensor([ 0.4885, -0.2399, -0.1683,  0.4050,  0.1653, -0.2837,  0.6834,  0.5796,
#         -0.1500,  0.0232], requires_grad=True), Parameter containing:
# tensor([[ 0.3187, -0.0864, -0.0791,  0.3552, -0.3156,  0.1266, -0.3565,  0.0300,
#          -0.1519,  0.3268],
#         [-0.2922, -0.1409,  0.2073, -0.3164, -0.0351,  0.2811,  0.2591, -0.1555,
#           0.0933, -0.1382]], requires_grad=True), Parameter containing:
# tensor([0.1031, 0.2317], requires_grad=True)]
#
# [Parameter containing:
# tensor([[ 0.7278,  0.5577],
#         [ 0.6352,  0.0956],
#         [ 0.3324, -0.3264],
#         [ 0.6709, -0.0710],
#         [-0.4461,  0.1535],
#         [-0.6749,  0.3092],
#         [-0.7044, -0.6852],
#         [-0.1276,  0.5372],
#         [ 0.5875,  0.4275],
#         [ 0.4976, -0.0687]], requires_grad=True), Parameter containing:
# tensor([ 0.4890, -0.2398, -0.1682,  0.4054,  0.1654, -0.2836,  0.6838,  0.5797,
#         -0.1502,  0.0235], requires_grad=True), Parameter containing:
# tensor([[ 0.3203, -0.0860, -0.0791,  0.3559, -0.3160,  0.1263, -0.3588,  0.0309,
#          -0.1510,  0.3272],
#         [-0.2938, -0.1414,  0.2073, -0.3171, -0.0347,  0.2814,  0.2614, -0.1564,
#           0.0924, -0.1385]], requires_grad=True), Parameter containing:
# tensor([0.1031, 0.2317], requires_grad=True)]
#
# [Parameter containing:
# tensor([[ 0.7283,  0.5585],
#         [ 0.6352,  0.0957],
#         [ 0.3322, -0.3266],
#         [ 0.6715, -0.0700],
#         [-0.4465,  0.1529],
#         [-0.6751,  0.3090],
#         [-0.7053, -0.6860],
#         [-0.1273,  0.5375],
#         [ 0.5874,  0.4272],
#         [ 0.4980, -0.0683]], requires_grad=True), Parameter containing:
# tensor([ 0.4894, -0.2398, -0.1682,  0.4059,  0.1655, -0.2836,  0.6842,  0.5797,
#         -0.1504,  0.0237], requires_grad=True), Parameter containing:
# tensor([[ 0.3220, -0.0855, -0.0792,  0.3566, -0.3164,  0.1260, -0.3611,  0.0317,
#          -0.1501,  0.3275],
#         [-0.2955, -0.1418,  0.2074, -0.3178, -0.0343,  0.2817,  0.2637, -0.1573,
#           0.0915, -0.1388]], requires_grad=True), Parameter containing:
# tensor([0.1030, 0.2317], requires_grad=True)]
#
# [Parameter containing:
# tensor([[ 0.7288,  0.5593],
#         [ 0.6353,  0.0957],
#         [ 0.3321, -0.3269],
#         [ 0.6720, -0.0690],
#         [-0.4469,  0.1524],
#         [-0.6753,  0.3088],
#         [-0.7061, -0.6868],
#         [-0.1271,  0.5377],
#         [ 0.5872,  0.4269],
#         [ 0.4983, -0.0678]], requires_grad=True), Parameter containing:
# tensor([ 0.4898, -0.2398, -0.1681,  0.4063,  0.1656, -0.2835,  0.6847,  0.5798,
#         -0.1506,  0.0240], requires_grad=True), Parameter containing:
# tensor([[ 0.3236, -0.0851, -0.0792,  0.3573, -0.3168,  0.1257, -0.3634,  0.0326,
#          -0.1492,  0.3278],
#         [-0.2971, -0.1423,  0.2074, -0.3185, -0.0339,  0.2820,  0.2659, -0.1581,
#           0.0906, -0.1391]], requires_grad=True), Parameter containing:
# tensor([0.1030, 0.2318], requires_grad=True)]
#
# [Parameter containing:
# tensor([[ 0.7292,  0.5601],
#         [ 0.6353,  0.0958],
#         [ 0.3319, -0.3271],
#         [ 0.6725, -0.0681],
#         [-0.4473,  0.1518],
#         [-0.6754,  0.3087],
#         [-0.7069, -0.6876],
#         [-0.1268,  0.5380],
#         [ 0.5870,  0.4266],
#         [ 0.4987, -0.0674]], requires_grad=True), Parameter containing:
# tensor([ 0.4903, -0.2397, -0.1681,  0.4067,  0.1657, -0.2835,  0.6851,  0.5799,
#         -0.1507,  0.0243], requires_grad=True), Parameter containing:
# tensor([[ 0.3251, -0.0846, -0.0793,  0.3580, -0.3172,  0.1255, -0.3656,  0.0335,
#          -0.1484,  0.3281],
#         [-0.2986, -0.1427,  0.2075, -0.3192, -0.0335,  0.2822,  0.2681, -0.1590,
#           0.0898, -0.1395]], requires_grad=True), Parameter containing:
# tensor([0.1030, 0.2318], requires_grad=True)]
#
# [Parameter containing:
# tensor([[ 0.7297,  0.5609],
#         [ 0.6353,  0.0959],
#         [ 0.3317, -0.3273],
#         [ 0.6731, -0.0671],
#         [-0.4477,  0.1513],
#         [-0.6756,  0.3085],
#         [-0.7077, -0.6883],
#         [-0.1266,  0.5383],
#         [ 0.5868,  0.4263],
#         [ 0.4990, -0.0670]], requires_grad=True), Parameter containing:
# tensor([ 0.4907, -0.2397, -0.1680,  0.4071,  0.1658, -0.2834,  0.6855,  0.5800,
#         -0.1509,  0.0245], requires_grad=True), Parameter containing:
# tensor([[ 0.3267, -0.0842, -0.0793,  0.3586, -0.3176,  0.1252, -0.3677,  0.0343,
#          -0.1475,  0.3284],
#         [-0.3002, -0.1432,  0.2075, -0.3198, -0.0331,  0.2825,  0.2703, -0.1598,
#           0.0889, -0.1398]], requires_grad=True), Parameter containing:
# tensor([0.1029, 0.2318], requires_grad=True)]
#
# [Parameter containing:
# tensor([[ 0.7301,  0.5616],
#         [ 0.6354,  0.0959],
#         [ 0.3316, -0.3275],
#         [ 0.6736, -0.0662],
#         [-0.4481,  0.1508],
#         [-0.6757,  0.3083],
#         [-0.7085, -0.6891],
#         [-0.1263,  0.5386],
#         [ 0.5867,  0.4260],
#         [ 0.4993, -0.0665]], requires_grad=True), Parameter containing:
# tensor([ 0.4911, -0.2397, -0.1680,  0.4075,  0.1659, -0.2834,  0.6859,  0.5800,
#         -0.1511,  0.0248], requires_grad=True), Parameter containing:
# tensor([[ 0.3282, -0.0838, -0.0793,  0.3593, -0.3180,  0.1249, -0.3699,  0.0351,
#          -0.1467,  0.3287],
#         [-0.3017, -0.1436,  0.2075, -0.3205, -0.0328,  0.2828,  0.2724, -0.1606,
#           0.0881, -0.1401]], requires_grad=True), Parameter containing:
# tensor([0.1029, 0.2318], requires_grad=True)]
#
# [Parameter containing:
# tensor([[ 0.7305,  0.5624],
#         [ 0.6354,  0.0960],
#         [ 0.3314, -0.3278],
#         [ 0.6741, -0.0653],
#         [-0.4485,  0.1502],
#         [-0.6759,  0.3082],
#         [-0.7093, -0.6898],
#         [-0.1261,  0.5388],
#         [ 0.5865,  0.4257],
#         [ 0.4996, -0.0661]], requires_grad=True), Parameter containing:
# tensor([ 0.4915, -0.2396, -0.1679,  0.4079,  0.1660, -0.2834,  0.6863,  0.5801,
#         -0.1512,  0.0251], requires_grad=True), Parameter containing:
# tensor([[ 0.3297, -0.0834, -0.0794,  0.3599, -0.3184,  0.1246, -0.3720,  0.0359,
#          -0.1459,  0.3290],
#         [-0.3032, -0.1440,  0.2076, -0.3211, -0.0324,  0.2831,  0.2746, -0.1615,
#           0.0873, -0.1404]], requires_grad=True), Parameter containing:
# tensor([0.1029, 0.2319], requires_grad=True)]
#
# [Parameter containing:
# tensor([[ 0.7310,  0.5631],
#         [ 0.6355,  0.0961],
#         [ 0.3313, -0.3280],
#         [ 0.6745, -0.0644],
#         [-0.4488,  0.1497],
#         [-0.6760,  0.3080],
#         [-0.7100, -0.6906],
#         [-0.1259,  0.5391],
#         [ 0.5864,  0.4254],
#         [ 0.5000, -0.0657]], requires_grad=True), Parameter containing:
# tensor([ 0.4919, -0.2396, -0.1679,  0.4083,  0.1661, -0.2833,  0.6867,  0.5802,
#         -0.1514,  0.0253], requires_grad=True), Parameter containing:
# tensor([[ 0.3312, -0.0830, -0.0794,  0.3605, -0.3187,  0.1244, -0.3741,  0.0367,
#          -0.1451,  0.3293],
#         [-0.3047, -0.1444,  0.2076, -0.3217, -0.0320,  0.2833,  0.2766, -0.1622,
#           0.0865, -0.1406]], requires_grad=True), Parameter containing:
# tensor([0.1028, 0.2319], requires_grad=True)]
#
# [Parameter containing:
# tensor([[ 0.7314,  0.5639],
#         [ 0.6355,  0.0961],
#         [ 0.3311, -0.3282],
#         [ 0.6750, -0.0635],
#         [-0.4492,  0.1492],
#         [-0.6762,  0.3079],
#         [-0.7108, -0.6913],
#         [-0.1256,  0.5394],
#         [ 0.5862,  0.4252],
#         [ 0.5003, -0.0653]], requires_grad=True), Parameter containing:
# tensor([ 0.4923, -0.2396, -0.1678,  0.4087,  0.1662, -0.2833,  0.6871,  0.5803,
#         -0.1515,  0.0256], requires_grad=True), Parameter containing:
# tensor([[ 0.3326, -0.0826, -0.0795,  0.3612, -0.3191,  0.1241, -0.3761,  0.0375,
#          -0.1444,  0.3296],
#         [-0.3061, -0.1448,  0.2076, -0.3224, -0.0317,  0.2836,  0.2787, -0.1630,
#           0.0858, -0.1409]], requires_grad=True), Parameter containing:
# tensor([0.1028, 0.2319], requires_grad=True)]
#
# [Parameter containing:
# tensor([[ 0.7318,  0.5646],
#         [ 0.6355,  0.0962],
#         [ 0.3309, -0.3284],
#         [ 0.6755, -0.0627],
#         [-0.4495,  0.1487],
#         [-0.6763,  0.3077],
#         [-0.7116, -0.6920],
#         [-0.1254,  0.5396],
#         [ 0.5861,  0.4249],
#         [ 0.5006, -0.0649]], requires_grad=True), Parameter containing:
# tensor([ 0.4927, -0.2395, -0.1678,  0.4090,  0.1663, -0.2832,  0.6875,  0.5803,
#         -0.1517,  0.0258], requires_grad=True), Parameter containing:
# tensor([[ 0.3340, -0.0822, -0.0795,  0.3618, -0.3194,  0.1238, -0.3781,  0.0383,
#          -0.1436,  0.3299],
#         [-0.3075, -0.1452,  0.2077, -0.3230, -0.0313,  0.2838,  0.2807, -0.1638,
#           0.0850, -0.1412]], requires_grad=True), Parameter containing:
# tensor([0.1028, 0.2320], requires_grad=True)]
#
# [Parameter containing:
# tensor([[ 0.7322,  0.5653],
#         [ 0.6356,  0.0962],
#         [ 0.3308, -0.3286],
#         [ 0.6760, -0.0618],
#         [-0.4499,  0.1482],
#         [-0.6765,  0.3076],
#         [-0.7123, -0.6928],
#         [-0.1251,  0.5399],
#         [ 0.5859,  0.4247],
#         [ 0.5009, -0.0646]], requires_grad=True), Parameter containing:
# tensor([ 0.4931, -0.2395, -0.1677,  0.4094,  0.1664, -0.2832,  0.6879,  0.5804,
#         -0.1518,  0.0260], requires_grad=True), Parameter containing:
# tensor([[ 0.3354, -0.0818, -0.0795,  0.3624, -0.3198,  0.1236, -0.3801,  0.0390,
#          -0.1429,  0.3302],
#         [-0.3089, -0.1455,  0.2077, -0.3236, -0.0309,  0.2841,  0.2827, -0.1646,
#           0.0843, -0.1415]], requires_grad=True), Parameter containing:
# tensor([0.1028, 0.2320], requires_grad=True)]
#
# [Parameter containing:
# tensor([[ 0.7326,  0.5660],
#         [ 0.6356,  0.0963],
#         [ 0.3306, -0.3288],
#         [ 0.6764, -0.0609],
#         [-0.4503,  0.1478],
#         [-0.6766,  0.3074],
#         [-0.7131, -0.6935],
#         [-0.1249,  0.5402],
#         [ 0.5858,  0.4244],
#         [ 0.5012, -0.0642]], requires_grad=True), Parameter containing:
# tensor([ 0.4935, -0.2395, -0.1677,  0.4098,  0.1665, -0.2831,  0.6883,  0.5805,
#         -0.1520,  0.0263], requires_grad=True), Parameter containing:
# tensor([[ 0.3368, -0.0815, -0.0796,  0.3630, -0.3202,  0.1233, -0.3821,  0.0398,
#          -0.1421,  0.3304],
#         [-0.3103, -0.1459,  0.2078, -0.3242, -0.0306,  0.2844,  0.2846, -0.1653,
#           0.0835, -0.1418]], requires_grad=True), Parameter containing:
# tensor([0.1027, 0.2320], requires_grad=True)]
#
# [Parameter containing:
# tensor([[ 0.7330,  0.5667],
#         [ 0.6357,  0.0964],
#         [ 0.3305, -0.3290],
#         [ 0.6769, -0.0601],
#         [-0.4506,  0.1473],
#         [-0.6768,  0.3073],
#         [-0.7138, -0.6942],
#         [-0.1247,  0.5404],
#         [ 0.5857,  0.4242],
# ...
#         [-0.6794,  0.3046],
#         [-0.7280, -0.7076],
#         [-0.1202,  0.5454],
#         [ 0.5834,  0.4200],
#         [ 0.5066, -0.0568]], requires_grad=True), Parameter containing:
# tensor([ 0.5012, -0.2388, -0.1667,  0.4171,  0.1682, -0.2823,  0.6962,  0.5820,
#         -0.1546,  0.0310], requires_grad=True), Parameter containing:
# tensor([[ 0.3627, -0.0747, -0.0803,  0.3743, -0.3269,  0.1186, -0.4192,  0.0540,
#          -0.1288,  0.3355],
#         [-0.3362, -0.1527,  0.2085, -0.3355, -0.0238,  0.2891,  0.3217, -0.1795,
#           0.0702, -0.1468]], requires_grad=True), Parameter containing:
# tensor([0.1022, 0.2325], requires_grad=True)]
# [Parameter containing:
# tensor([[ 0.7406,  0.5804],
#         [ 0.6365,  0.0976],
#         [ 0.3278, -0.3329],
#         [ 0.6851, -0.0447],
#         [-0.4572,  0.1380],
#         [-0.6795,  0.3045],
#         [-0.7286, -0.7082],
#         [-0.1200,  0.5456],
#         [ 0.5833,  0.4198],
#         [ 0.5068, -0.0565]], requires_grad=True), Parameter containing:
# tensor([ 0.5015, -0.2388, -0.1667,  0.4174,  0.1683, -0.2823,  0.6965,  0.5820,
#         -0.1547,  0.0312], requires_grad=True), Parameter containing:
# tensor([[ 0.3637, -0.0745, -0.0804,  0.3747, -0.3272,  0.1184, -0.4207,  0.0546,
#          -0.1283,  0.3357],
#         [-0.3372, -0.1529,  0.2086, -0.3359, -0.0236,  0.2893,  0.3232, -0.1801,
#           0.0697, -0.1470]], requires_grad=True), Parameter containing:
# tensor([0.1022, 0.2325], requires_grad=True)]
#
# [Parameter containing:
# tensor([[ 0.7409,  0.5809],
#         [ 0.6365,  0.0977],
#         [ 0.3277, -0.3331],
#         [ 0.6854, -0.0441],
#         [-0.4575,  0.1376],
#         [-0.6796,  0.3044],
#         [-0.7292, -0.7087],
#         [-0.1198,  0.5458],
#         [ 0.5833,  0.4197],
#         [ 0.5070, -0.0562]], requires_grad=True), Parameter containing:
# tensor([ 0.5018, -0.2387, -0.1666,  0.4177,  0.1684, -0.2822,  0.6968,  0.5821,
#         -0.1548,  0.0313], requires_grad=True), Parameter containing:
# tensor([[ 0.3647, -0.0742, -0.0804,  0.3752, -0.3274,  0.1183, -0.4221,  0.0551,
#          -0.1278,  0.3359],
#         [-0.3382, -0.1532,  0.2086, -0.3364, -0.0233,  0.2894,  0.3247, -0.1806,
#           0.0692, -0.1472]], requires_grad=True), Parameter containing:
# tensor([0.1022, 0.2325], requires_grad=True)]
#
# [Parameter containing:
# tensor([[ 0.7412,  0.5815],
#         [ 0.6365,  0.0977],
#         [ 0.3275, -0.3332],
#         [ 0.6857, -0.0435],
#         [-0.4578,  0.1373],
#         [-0.6797,  0.3043],
#         [-0.7298, -0.7093],
#         [-0.1196,  0.5460],
#         [ 0.5832,  0.4195],
#         [ 0.5072, -0.0559]], requires_grad=True), Parameter containing:
# tensor([ 0.5021, -0.2387, -0.1666,  0.4180,  0.1684, -0.2822,  0.6972,  0.5821,
#         -0.1549,  0.0315], requires_grad=True), Parameter containing:
# tensor([[ 0.3657, -0.0739, -0.0804,  0.3756, -0.3277,  0.1181, -0.4235,  0.0557,
#          -0.1273,  0.3361],
#         [-0.3392, -0.1534,  0.2086, -0.3368, -0.0230,  0.2896,  0.3261, -0.1812,
#           0.0687, -0.1474]], requires_grad=True), Parameter containing:
# tensor([0.1022, 0.2325], requires_grad=True)]
#
# [Parameter containing:
# tensor([[ 0.7415,  0.5820],
#         [ 0.6366,  0.0978],
#         [ 0.3274, -0.3334],
#         [ 0.6860, -0.0429],
#         [-0.4580,  0.1369],
#         [-0.6798,  0.3042],
#         [-0.7304, -0.7099],
#         [-0.1194,  0.5462],
#         [ 0.5831,  0.4194],
#         [ 0.5074, -0.0556]], requires_grad=True), Parameter containing:
# tensor([ 0.5024, -0.2387, -0.1665,  0.4183,  0.1685, -0.2822,  0.6975,  0.5822,
#         -0.1550,  0.0317], requires_grad=True), Parameter containing:
# tensor([[ 0.3667, -0.0737, -0.0805,  0.3760, -0.3280,  0.1179, -0.4250,  0.0562,
#          -0.1268,  0.3363],
#         [-0.3402, -0.1537,  0.2087, -0.3372, -0.0228,  0.2898,  0.3275, -0.1817,
#           0.0682, -0.1476]], requires_grad=True), Parameter containing:
# tensor([0.1022, 0.2326], requires_grad=True)]
#
# [Parameter containing:
# tensor([[ 0.7418,  0.5826],
#         [ 0.6366,  0.0979],
#         [ 0.3273, -0.3335],
#         [ 0.6864, -0.0423],
#         [-0.4583,  0.1365],
#         [-0.6799,  0.3041],
#         [-0.7310, -0.7104],
#         [-0.1193,  0.5464],
#         [ 0.5830,  0.4192],
#         [ 0.5076, -0.0554]], requires_grad=True), Parameter containing:
# tensor([ 0.5027, -0.2387, -0.1665,  0.4186,  0.1686, -0.2821,  0.6978,  0.5823,
#         -0.1551,  0.0319], requires_grad=True), Parameter containing:
# tensor([[ 0.3677, -0.0735, -0.0805,  0.3765, -0.3282,  0.1177, -0.4264,  0.0567,
#          -0.1263,  0.3365],
#         [-0.3412, -0.1539,  0.2087, -0.3377, -0.0225,  0.2900,  0.3289, -0.1823,
#           0.0677, -0.1478]], requires_grad=True), Parameter containing:
# tensor([0.1022, 0.2326], requires_grad=True)]
#
# [Parameter containing:
# tensor([[ 0.7421,  0.5831],
#         [ 0.6366,  0.0979],
#         [ 0.3272, -0.3337],
#         [ 0.6867, -0.0417],
#         [-0.4585,  0.1362],
#         [-0.6800,  0.3040],
#         [-0.7316, -0.7110],
#         [-0.1191,  0.5467],
#         [ 0.5830,  0.4191],
#         [ 0.5078, -0.0551]], requires_grad=True), Parameter containing:
# tensor([ 0.5031, -0.2386, -0.1665,  0.4189,  0.1686, -0.2821,  0.6981,  0.5823,
#         -0.1552,  0.0321], requires_grad=True), Parameter containing:
# tensor([[ 0.3687, -0.0732, -0.0805,  0.3769, -0.3285,  0.1176, -0.4277,  0.0573,
#          -0.1258,  0.3367],
#         [-0.3422, -0.1541,  0.2087, -0.3381, -0.0223,  0.2901,  0.3303, -0.1828,
#           0.0673, -0.1480]], requires_grad=True), Parameter containing:
# tensor([0.1022, 0.2326], requires_grad=True)]
#
# [Parameter containing:
# tensor([[ 0.7424,  0.5836],
#         [ 0.6367,  0.0980],
#         [ 0.3271, -0.3338],
#         [ 0.6870, -0.0411],
#         [-0.4588,  0.1358],
#         [-0.6801,  0.3039],
#         [-0.7322, -0.7115],
#         [-0.1189,  0.5469],
#         [ 0.5829,  0.4189],
#         [ 0.5080, -0.0548]], requires_grad=True), Parameter containing:
# tensor([ 0.5034, -0.2386, -0.1664,  0.4191,  0.1687, -0.2821,  0.6984,  0.5824,
#         -0.1553,  0.0323], requires_grad=True), Parameter containing:
# tensor([[ 0.3696, -0.0730, -0.0805,  0.3773, -0.3287,  0.1174, -0.4291,  0.0578,
#          -0.1254,  0.3368],
#         [-0.3431, -0.1544,  0.2087, -0.3385, -0.0220,  0.2903,  0.3317, -0.1833,
#           0.0668, -0.1482]], requires_grad=True), Parameter containing:
# tensor([0.1021, 0.2326], requires_grad=True)]
#
# [Parameter containing:
# tensor([[ 0.7427,  0.5842],
#         [ 0.6367,  0.0980],
#         [ 0.3270, -0.3339],
#         [ 0.6873, -0.0405],
#         [-0.4591,  0.1355],
#         [-0.6802,  0.3038],
#         [-0.7328, -0.7121],
#         [-0.1187,  0.5471],
#         [ 0.5828,  0.4188],
#         [ 0.5082, -0.0546]], requires_grad=True), Parameter containing:
# tensor([ 0.5037, -0.2386, -0.1664,  0.4194,  0.1688, -0.2821,  0.6987,  0.5824,
#         -0.1553,  0.0324], requires_grad=True), Parameter containing:
# tensor([[ 0.3706, -0.0728, -0.0806,  0.3777, -0.3290,  0.1172, -0.4305,  0.0583,
#          -0.1249,  0.3370],
#         [-0.3441, -0.1546,  0.2088, -0.3389, -0.0217,  0.2905,  0.3330, -0.1838,
#           0.0663, -0.1483]], requires_grad=True), Parameter containing:
# tensor([0.1021, 0.2326], requires_grad=True)]
#
# [Parameter containing:
# tensor([[ 0.7430,  0.5847],
#         [ 0.6367,  0.0981],
#         [ 0.3269, -0.3341],
#         [ 0.6876, -0.0400],
#         [-0.4593,  0.1351],
#         [-0.6803,  0.3037],
#         [-0.7334, -0.7126],
#         [-0.1185,  0.5473],
#         [ 0.5827,  0.4186],
#         [ 0.5084, -0.0543]], requires_grad=True), Parameter containing:
# tensor([ 0.5040, -0.2386, -0.1664,  0.4197,  0.1688, -0.2820,  0.6990,  0.5825,
#         -0.1554,  0.0326], requires_grad=True), Parameter containing:
# tensor([[ 0.3715, -0.0725, -0.0806,  0.3781, -0.3292,  0.1170, -0.4318,  0.0588,
#          -0.1245,  0.3372],
#         [-0.3450, -0.1548,  0.2088, -0.3393, -0.0215,  0.2907,  0.3344, -0.1844,
#           0.0659, -0.1485]], requires_grad=True), Parameter containing:
# tensor([0.1021, 0.2326], requires_grad=True)]
#
# [Parameter containing:
# tensor([[ 0.7433,  0.5852],
#         [ 0.6368,  0.0981],
#         [ 0.3268, -0.3342],
#         [ 0.6878, -0.0394],
#         [-0.4595,  0.1348],
#         [-0.6804,  0.3036],
#         [-0.7339, -0.7132],
#         [-0.1183,  0.5475],
#         [ 0.5827,  0.4185],
#         [ 0.5086, -0.0540]], requires_grad=True), Parameter containing:
# tensor([ 0.5043, -0.2385, -0.1663,  0.4200,  0.1689, -0.2820,  0.6993,  0.5825,
#         -0.1555,  0.0328], requires_grad=True), Parameter containing:
# tensor([[ 0.3724, -0.0723, -0.0806,  0.3785, -0.3295,  0.1169, -0.4332,  0.0593,
#          -0.1240,  0.3374],
#         [-0.3459, -0.1551,  0.2088, -0.3397, -0.0212,  0.2908,  0.3357, -0.1849,
#           0.0654, -0.1487]], requires_grad=True), Parameter containing:
# tensor([0.1021, 0.2326], requires_grad=True)]
#
# [Parameter containing:
# tensor([[ 0.7435,  0.5857],
#         [ 0.6368,  0.0982],
#         [ 0.3267, -0.3344],
#         [ 0.6881, -0.0388],
#         [-0.4598,  0.1344],
#         [-0.6805,  0.3035],
#         [-0.7345, -0.7137],
#         [-0.1182,  0.5477],
#         [ 0.5826,  0.4184],
#         [ 0.5087, -0.0538]], requires_grad=True), Parameter containing:
# tensor([ 0.5046, -0.2385, -0.1663,  0.4202,  0.1689, -0.2820,  0.6996,  0.5826,
#         -0.1556,  0.0329], requires_grad=True), Parameter containing:
# tensor([[ 0.3733, -0.0721, -0.0807,  0.3789, -0.3297,  0.1167, -0.4345,  0.0598,
#          -0.1236,  0.3376],
#         [-0.3468, -0.1553,  0.2089, -0.3401, -0.0210,  0.2910,  0.3370, -0.1854,
#           0.0650, -0.1489]], requires_grad=True), Parameter containing:
# tensor([0.1021, 0.2327], requires_grad=True)]
#
# [Parameter containing:
# tensor([[ 0.7438,  0.5862],
#         [ 0.6368,  0.0982],
#         [ 0.3267, -0.3345],
#         [ 0.6884, -0.0383],
#         [-0.4600,  0.1341],
#         [-0.6806,  0.3033],
#         [-0.7351, -0.7142],
#         [-0.1180,  0.5479],
#         [ 0.5825,  0.4182],
#         [ 0.5089, -0.0535]], requires_grad=True), Parameter containing:
# tensor([ 0.5049, -0.2385, -0.1662,  0.4205,  0.1690, -0.2819,  0.6999,  0.5827,
#         -0.1557,  0.0331], requires_grad=True), Parameter containing:
# tensor([[ 0.3742, -0.0719, -0.0807,  0.3793, -0.3300,  0.1165, -0.4358,  0.0603,
#          -0.1231,  0.3377],
#         [-0.3477, -0.1555,  0.2089, -0.3405, -0.0208,  0.2912,  0.3383, -0.1859,
#           0.0645, -0.1491]], requires_grad=True), Parameter containing:
# tensor([0.1021, 0.2327], requires_grad=True)]
#
# [Parameter containing:
# tensor([[ 0.7441,  0.5867],
#         [ 0.6368,  0.0983],
#         [ 0.3266, -0.3346],
#         [ 0.6887, -0.0377],
#         [-0.4603,  0.1337],
#         [-0.6807,  0.3032],
#         [-0.7357, -0.7148],
#         [-0.1178,  0.5481],
#         [ 0.5825,  0.4181],
#         [ 0.5091, -0.0533]], requires_grad=True), Parameter containing:
# tensor([ 0.5051, -0.2385, -0.1662,  0.4208,  0.1691, -0.2819,  0.7002,  0.5827,
#         -0.1558,  0.0333], requires_grad=True), Parameter containing:
# tensor([[ 0.3751, -0.0716, -0.0807,  0.3797, -0.3302,  0.1164, -0.4371,  0.0608,
#          -0.1227,  0.3379],
#         [-0.3486, -0.1557,  0.2089, -0.3409, -0.0205,  0.2913,  0.3396, -0.1864,
#           0.0641, -0.1492]], requires_grad=True), Parameter containing:
# tensor([0.1021, 0.2327], requires_grad=True)]
#
# [Parameter containing:
# tensor([[ 0.7443,  0.5872],
#         [ 0.6369,  0.0983],
#         [ 0.3265, -0.3348],
#         [ 0.6890, -0.0372],
#         [-0.4605,  0.1334],
#         [-0.6808,  0.3031],
#         [-0.7362, -0.7153],
#         [-0.1176,  0.5483],
#         [ 0.5824,  0.4180],
#         [ 0.5093, -0.0530]], requires_grad=True), Parameter containing:
# tensor([ 0.5054, -0.2384, -0.1662,  0.4210,  0.1691, -0.2819,  0.7005,  0.5828,
#         -0.1558,  0.0335], requires_grad=True), Parameter containing:
# tensor([[ 0.3760, -0.0714, -0.0808,  0.3801, -0.3305,  0.1162, -0.4383,  0.0613,
#          -0.1222,  0.3381],
#         [-0.3495, -0.1559,  0.2090, -0.3413, -0.0203,  0.2915,  0.3409, -0.1869,
#           0.0637, -0.1494]], requires_grad=True), Parameter containing:
# tensor([0.1021, 0.2327], requires_grad=True)]
#
# [Parameter containing:
# tensor([[ 0.7446,  0.5877],
#         [ 0.6369,  0.0984],
#         [ 0.3264, -0.3349],
#         [ 0.6893, -0.0366],
#         [-0.4607,  0.1331],
#         [-0.6809,  0.3031],
#         [-0.7368, -0.7158],
#         [-0.1174,  0.5485],
#         [ 0.5823,  0.4178],
#         [ 0.5095, -0.0528]], requires_grad=True), Parameter containing:
# tensor([ 0.5057, -0.2384, -0.1661,  0.4213,  0.1692, -0.2818,  0.7008,  0.5828,
#         -0.1559,  0.0336], requires_grad=True), Parameter containing:
# tensor([[ 0.3769, -0.0712, -0.0808,  0.3805, -0.3307,  0.1161, -0.4396,  0.0618,
#          -0.1218,  0.3382],
#         [-0.3504, -0.1562,  0.2090, -0.3417, -0.0200,  0.2916,  0.3422, -0.1873,
#           0.0632, -0.1496]], requires_grad=True), Parameter containing:
# tensor([0.1020, 0.2327], requires_grad=True)]
#
# [Parameter containing:
# tensor([[ 0.7449,  0.5882],
#         [ 0.6369,  0.0984],
#         [ 0.3263, -0.3350],
#         [ 0.6895, -0.0361],
#         [-0.4610,  0.1327],
#         [-0.6810,  0.3030],
#         [-0.7373, -0.7163],
#         [-0.1173,  0.5487],
#         [ 0.5823,  0.4177],
#         [ 0.5096, -0.0525]], requires_grad=True), Parameter containing:
# tensor([ 0.5060, -0.2384, -0.1661,  0.4216,  0.1692, -0.2818,  0.7011,  0.5829,
#         -0.1560,  0.0338], requires_grad=True), Parameter containing:
# tensor([[ 0.3778, -0.0710, -0.0808,  0.3809, -0.3309,  0.1159, -0.4409,  0.0623,
#          -0.1214,  0.3384],
#         [-0.3513, -0.1564,  0.2090, -0.3421, -0.0198,  0.2918,  0.3434, -0.1878,
#           0.0628, -0.1497]], requires_grad=True), Parameter containing:
# tensor([0.1020, 0.2327], requires_grad=True)]
#
# [Parameter containing:
# tensor([[ 0.7451,  0.5887],
#         [ 0.6370,  0.0985],
#         [ 0.3262, -0.3351],
#         [ 0.6898, -0.0356],
#         [-0.4612,  0.1324],
#         [-0.6811,  0.3029],
#         [-0.7379, -0.7168],
#         [-0.1171,  0.5489],
#         [ 0.5822,  0.4176],
#         [ 0.5098, -0.0523]], requires_grad=True), Parameter containing:
# tensor([ 0.5063, -0.2383, -0.1661,  0.4218,  0.1693, -0.2818,  0.7014,  0.5830,
#         -0.1561,  0.0339], requires_grad=True), Parameter containing:
# tensor([[ 0.3786, -0.0708, -0.0808,  0.3813, -0.3312,  0.1158, -0.4421,  0.0628,
#          -0.1210,  0.3386],
#         [-0.3521, -0.1566,  0.2090, -0.3425, -0.0196,  0.2919,  0.3447, -0.1883,
#           0.0624, -0.1499]], requires_grad=True), Parameter containing:
# tensor([0.1020, 0.2327], requires_grad=True)]
#
# [Parameter containing:
# tensor([[ 0.7454,  0.5892],
#         [ 0.6370,  0.0985],
#         [ 0.3261, -0.3353],
#         [ 0.6901, -0.0350],
#         [-0.4614,  0.1321],
#         [-0.6812,  0.3028],
#         [-0.7384, -0.7173],
#         [-0.1169,  0.5491],
#         [ 0.5821,  0.4175],
#         [ 0.5100, -0.0521]], requires_grad=True), Parameter containing:
# tensor([ 0.5066, -0.2383, -0.1660,  0.4221,  0.1693, -0.2818,  0.7017,  0.5830,
#         -0.1562,  0.0341], requires_grad=True), Parameter containing:
# tensor([[ 0.3795, -0.0706, -0.0809,  0.3817, -0.3314,  0.1156, -0.4433,  0.0633,
#          -0.1206,  0.3387],
#         [-0.3530, -0.1568,  0.2091, -0.3429, -0.0193,  0.2921,  0.3459, -0.1888,
#           0.0620, -0.1501]], requires_grad=True), Parameter containing:
# tensor([0.1020, 0.2327], requires_grad=True)]
#
# [Parameter containing:
# tensor([[ 0.7456,  0.5897],
#         [ 0.6370,  0.0986],
#         [ 0.3260, -0.3354],
#         [ 0.6903, -0.0345],
#         [-0.4617,  0.1318],
#         [-0.6813,  0.3027],
#         [-0.7390, -0.7178],
#         [-0.1168,  0.5492],
#         [ 0.5821,  0.4173],
#         [ 0.5102, -0.0518]], requires_grad=True), Parameter containing:
# tensor([ 0.5069, -0.2383, -0.1660,  0.4223,  0.1694, -0.2817,  0.7020,  0.5831,
#         -0.1562,  0.0343], requires_grad=True), Parameter containing:
# tensor([[ 0.3803, -0.0704, -0.0809,  0.3820, -0.3316,  0.1154, -0.4445,  0.0637,
#          -0.1202,  0.3389],
#         [-0.3538, -0.1570,  0.2091, -0.3432, -0.0191,  0.2922,  0.3471, -0.1893,
#           0.0616, -0.1502]], requires_grad=True), Parameter containing:
# tensor([0.1020, 0.2327], requires_grad=True)]
